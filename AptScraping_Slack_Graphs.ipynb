# %% [markdown]
# # <font color=indianred> Goal: extract data for apartments in SF Neighborhoods from Craigslist

# %%
# Import dependencies
import pandas as pd
from bs4 import BeautifulSoup
import requests
import numpy as np
import re

# %%
# Neighborhood codes
lowernobhill = 20
nobhill = 19
pacheights = 23
russianhill = 27
marina = 17
northbeach = 22

# Set up parameters and response to link 
# Change nh= to the neighborhood you want to explore
url_base = 'https://sfbay.craigslist.org/search/sfc/apa?nh=20&nh=24&nh=17&nh=19&nh=22&nh=23&nh=27'
params = dict(max_bedrooms=2, min_bedrooms=2, max_price=3500, housing_type=1)
response = requests.get(url_base, params=params)
print(response.url)
# Out:
# https://sfbay.craigslist.org/search/sfc/apa?nh=20&nh=24&nh=17&nh=19&nh=22&nh=23&nh=27&max_bedrooms=2&min_bedrooms=2&max_price=3500&housing_type=1

# %%
# Connect to BeautifulSoup and define the parser as HTML
soup = BeautifulSoup(response.text, 'html.parser')

# Find all apts that fit the specified criteria and # of apts
apts = soup.find_all('p', attrs={'class':'result-info'})
print(len(apts))
# Out:
# 30

# %% [markdown]
# ## <font color=salmon> Parse through Craigslist results</font>

# %%
# results are returned as an iterable list
results = soup.find_all('li', class_="result-row")
list_results = []


# Loop through returned results
for result in results:
    # Error handling
    try:
        # Identify and return title of listing
        title = result.find('a', class_="result-title").text
        # Identify and return price of listing
        price = result.a.span.text.strip('$')
        # Identify number of rooms
        n_rooms = result.find('span', class_ = 'housing').text.split()
        # Identify and return link to listing
        link = result.a['href']
        # Identify posting date
        post_time = result.find('time')['datetime']
        post_time = pd.to_datetime(post_time)
        # Identify neighborhood
        neighborhood = result.find('span', class_= 'result-hood').text
        
        list_results.append({'#bedrooms': n_rooms, '$price': price,
                        'Post_Title': title, 'URL': link, 'Post_Time': post_time, 'Neighborhood': neighborhood})
        
        # Print results only if title, price, and link are available
        if (title and price and link):
            print('-------------')
            print(title)
            print(price)
            print(n_rooms)
            print(link)
            print(post_time)
            print(neighborhood)
    except AttributeError as e:
        print(e)
# Out:
# -------------
# Modern 2BR/1BA in Lower Pacific Heights
# 3495
# ['2br', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-modern-2br-1ba-in-lower/6818662471.html
# 2019-02-13 13:00:00
#  (lower pac hts)
# -------------
# SUTTER ST NR. PRESIDIO 2 BR APT. EXC. DESIRABLE LOCATIO & GREAT TRANS.
# 2900
# ['2br', '-', '850ft2', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-sutter-st-nr-presidio-2/6796761973.html
# 2019-02-13 11:18:00
#  (lower pac hts)
# -------------
# 2 Bedrooms flat -  1 Bath
# 3300
# ['2br', '-', '675ft2', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedrooms-flat-1-bath/6808841627.html
# 2019-02-13 10:51:00
#  (nob hill)
# -------------
# 2 Bedrooms flat -  1 Bath
# 3100
# ['2br', '-', '675ft2', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedrooms-flat-1-bath/6808839802.html
# 2019-02-13 10:51:00
#  (nob hill)
# -------------
# 2 BED SUNNY Remodeled; hdwd, quartz, Micro, dishwasher; 4 closets;
# 3300
# ['2br', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bed-sunny-remodeled/6815279146.html
# 2019-02-13 09:25:00
#  (lower nob hill)
# -------------
# Gold Mine Dr 2 Beds 1 Bath 900 sqft For Rent.
# 670
# ['2br', '-', '900ft2', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-gold-mine-dr-2-beds-1/6818364855.html
# 2019-02-13 08:23:00
#  (marina / cow hollow)
# -------------
# Stunning unit with clean modern design
# 3500
# ['2br', '-', '1038ft2', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-stunning-unit-with-clean/6818229683.html
# 2019-02-13 06:09:00
#  (russian hill)
# -------------
# 2 bedroom with hardwood and large rooms near Polk
# 3250
# ['2br', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedroom-with-hardwood/6818165978.html
# 2019-02-12 21:13:00
#  (nob hill)
# -------------
# Prime North Beach, Union @ Stockton 2BR/1BA, good size unit for rent..
# 3450
# ['2br', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-prime-north-beach-union/6813029028.html
# 2019-02-12 17:31:00
#  (north beach / telegraph hill)
# -------------
# Bright and Spacious - Newly renovated 1Br w/Den
# 3095
# ['2br', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-bright-and-spacious-newly/6816304843.html
# 2019-02-12 17:08:00
#  (lower nob hill)
# -------------
# Hyde/Clay Sts 2 bdrm, liv rm, xtra bonus rm, carpet, lar kit, grt loc
# 3100
# ['2br', '-', '850ft2', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-hyde-clay-sts-2-bdrm-liv/6817385660.html
# 2019-02-12 00:04:00
#  (nob hill)
# 'NoneType' object has no attribute 'text'
# -------------
# Bright and Spacious - Newly renovated 1Br w/Den
# 3095
# ['2br', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-bright-and-spacious-newly/6813415853.html
# 2019-02-11 23:27:00
#  (lower nob hill)
# -------------
# New Two Bedroom in Nob Hill
# 3495
# ['2br', '-', '750ft2', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-new-two-bedroom-in-nob/6814853385.html
# 2019-02-11 22:00:00
#  (nob hill)
# -------------
# 2 bedroom ​freshly remodeled. Clay & Mason
# 2988
# ['2br', '-', '515ft2', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedroom-freshly/6817218156.html
# 2019-02-11 16:26:00
#  (nob hill)
# -------------
# 2 Bedroom 1 Bathroom Recently Renovated Apt Available April 1
# 2950
# ['2br', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedroom-1-bathroom/6817209145.html
# 2019-02-11 16:12:00
#  (nob hill)
# -------------
# Charming 2/1, HW, laundry, great location!
# 3500
# ['2br', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-charming-2-1-hw-laundry/6814658751.html
# 2019-02-11 13:30:00
#  (north beach / telegraph hill)
# -------------
# 2 BR Available For Rent- $3400
# 3400
# ['2br', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-br-available-for-rent/6816486801.html
# 2019-02-10 19:27:00
#  (nob hill)
# -------------
# 2 BR Available For Rent- $3400
# 3400
# ['2br', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-br-available-for-rent/6816486616.html
# 2019-02-10 19:26:00
#  (nob hill)
# -------------
# 721 Geary #5 - $95 Move-In Special - Available Now!
# 3395
# ['2br', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-721-geary-5-95-move-in/6796974937.html
# 2019-02-10 19:16:00
#  (lower nob hill)
# -------------
# Room for Rent : 2 bedroom/1 bathroom
# 2000
# ['2br', '-', '1ft2', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-room-for-rent-2-bedroom-1/6816470635.html
# 2019-02-10 18:48:00
#  (russian hill)
# -------------
# SUTTER ST NR. PRESIDIO 2 BR APT. EXC. DESIRABLE LOCATIO & GREAT TRANS.
# 2950
# ['2br', '-', '850ft2', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-sutter-st-nr-presidio-2/6806241723.html
# 2019-02-10 13:01:00
#  (lower pac hts)
# -------------
# One room in 2bd 1bath apartment in lower nob hill
# 1850
# ['2br', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-one-room-in-2bd-1bath/6815860090.html
# 2019-02-09 21:04:00
#  (lower nob hill)
# -------------
# Beautiful Apartment-Lower Pac Heights
# 3400
# ['2br', '-']
# https://sfbay.craigslist.org/sfc/apa/d/beautiful-apartment-lower-pac-heights/6815538294.html
# 2019-02-09 11:50:00
#  (lower pac hts)
# -------------
# 2-3 Bedrooms + Bonus room + Split bathroom for Rent in North Beach
# 2999
# ['2br', '-', '900ft2', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-3-bedrooms-bonus-room/6815507957.html
# 2019-02-09 11:19:00
#  (north beach / telegraph hill)
# -------------
# 2 bedroom, 1 bathroom apartment
# 2700
# ['2br', '-', '675ft2', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedroom-1-bathroom/6811835800.html
# 2019-02-08 23:21:00
#  (nob hill)
# -------------
# Conveniently Located 2BR
# 3500
# ['2br', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-conveniently-located-2br/6814406969.html
# 2019-02-08 06:04:00
#  (pacific heights)
# -------------
# Beautiful 2 Bedroom 1 Bath with 2 Big Walking Closets
# 3195
# ['2br', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-beautiful-2-bedroom-1/6813850217.html
# 2019-02-07 10:25:00
#  (nob hill)
# -------------
# Spacious Floor Plan Loacted in Fun Neighborhood
# 3150
# ['2br', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-spacious-floor-plan/6807701982.html
# 2019-02-06 19:13:00
#  (nob hill)
# -------------
# Pine/Powell Sts 4 rm, 2 bd, liv rm, wd laminate flr, nr fin distric
# 3000
# ['2br', '-', '800ft2', '-']
# https://sfbay.craigslist.org/sfc/apa/d/san-francisco-pine-powell-sts-4-rm-2-bd/6813040619.html
# 2019-02-06 10:29:00
#  (nob hill)

# %% [markdown]
# ## <font color=salmon> Create DataFrame from Results </font>

# %%
# Create DataFrame
apt_df = pd.DataFrame(list_results)

# Clean data and remove text for room/ 
bedrooms = apt_df['#bedrooms']
rooms = []

for room in bedrooms:
    rooms.append(room[0].strip('br'))

apt_df['#rooms'] = rooms
apt_df['Post_Time'] = apt_df['Post_Time'].dt.date

apt_df
# Out:
#                #bedrooms $price                     Neighborhood   Post_Time  \
# 0               [2br, -]   3495                  (lower pac hts)  2019-02-13
# 1    [2br, -, 850ft2, -]   2900                  (lower pac hts)  2019-02-13
# 2    [2br, -, 675ft2, -]   3300                       (nob hill)  2019-02-13
# 3    [2br, -, 675ft2, -]   3100                       (nob hill)  2019-02-13
# 4               [2br, -]   3300                 (lower nob hill)  2019-02-13
# 5    [2br, -, 900ft2, -]    670            (marina / cow hollow)  2019-02-13
# 6   [2br, -, 1038ft2, -]   3500                   (russian hill)  2019-02-13
# 7               [2br, -]   3250                       (nob hill)  2019-02-12
# 8               [2br, -]   3450   (north beach / telegraph hill)  2019-02-12
# 9               [2br, -]   3095                 (lower nob hill)  2019-02-12
# 10   [2br, -, 850ft2, -]   3100                       (nob hill)  2019-02-12
# 11              [2br, -]   3095                 (lower nob hill)  2019-02-11
# 12   [2br, -, 750ft2, -]   3495                       (nob hill)  2019-02-11
# 13   [2br, -, 515ft2, -]   2988                       (nob hill)  2019-02-11
# 14              [2br, -]   2950                       (nob hill)  2019-02-11
# 15              [2br, -]   3500   (north beach / telegraph hill)  2019-02-11
# 16              [2br, -]   3400                       (nob hill)  2019-02-10
# 17              [2br, -]   3400                       (nob hill)  2019-02-10
# 18              [2br, -]   3395                 (lower nob hill)  2019-02-10
# 19     [2br, -, 1ft2, -]   2000                   (russian hill)  2019-02-10
# 20   [2br, -, 850ft2, -]   2950                  (lower pac hts)  2019-02-10
# 21              [2br, -]   1850                 (lower nob hill)  2019-02-09
# 22              [2br, -]   3400                  (lower pac hts)  2019-02-09
# 23   [2br, -, 900ft2, -]   2999   (north beach / telegraph hill)  2019-02-09
# 24   [2br, -, 675ft2, -]   2700                       (nob hill)  2019-02-08
# 25              [2br, -]   3500                (pacific heights)  2019-02-08
# 26              [2br, -]   3195                       (nob hill)  2019-02-07
# 27              [2br, -]   3150                       (nob hill)  2019-02-06
# 28   [2br, -, 800ft2, -]   3000                       (nob hill)  2019-02-06
#
#                                            Post_Title  \
# 0             Modern 2BR/1BA in Lower Pacific Heights
# 1   SUTTER ST NR. PRESIDIO 2 BR APT. EXC. DESIRABL...
# 2                           2 Bedrooms flat -  1 Bath
# 3                           2 Bedrooms flat -  1 Bath
# 4   2 BED SUNNY Remodeled; hdwd, quartz, Micro, di...
# 5       Gold Mine Dr 2 Beds 1 Bath 900 sqft For Rent.
# 6              Stunning unit with clean modern design
# 7   2 bedroom with hardwood and large rooms near Polk
# 8   Prime North Beach, Union @ Stockton 2BR/1BA, g...
# 9     Bright and Spacious - Newly renovated 1Br w/Den
# 10  Hyde/Clay Sts 2 bdrm, liv rm, xtra bonus rm, c...
# 11    Bright and Spacious - Newly renovated 1Br w/Den
# 12                        New Two Bedroom in Nob Hill
# 13         2 bedroom ​freshly remodeled. Clay & Mason
# 14  2 Bedroom 1 Bathroom Recently Renovated Apt Av...
# 15         Charming 2/1, HW, laundry, great location!
# 16                     2 BR Available For Rent- $3400
# 17                     2 BR Available For Rent- $3400
# 18  721 Geary #5 - $95 Move-In Special - Available...
# 19               Room for Rent : 2 bedroom/1 bathroom
# 20  SUTTER ST NR. PRESIDIO 2 BR APT. EXC. DESIRABL...
# 21  One room in 2bd 1bath apartment in lower nob hill
# 22              Beautiful Apartment-Lower Pac Heights
# 23  2-3 Bedrooms + Bonus room + Split bathroom for...
# 24                    2 bedroom, 1 bathroom apartment
# 25                           Conveniently Located 2BR
# 26  Beautiful 2 Bedroom 1 Bath with 2 Big Walking ...
# 27    Spacious Floor Plan Loacted in Fun Neighborhood
# 28  Pine/Powell Sts 4 rm, 2 bd, liv rm, wd laminat...
#
#                                                   URL #rooms
# 0   https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 1   https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 2   https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 3   https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 4   https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 5   https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 6   https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 7   https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 8   https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 9   https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 10  https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 11  https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 12  https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 13  https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 14  https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 15  https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 16  https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 17  https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 18  https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 19  https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 20  https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 21  https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 22  https://sfbay.craigslist.org/sfc/apa/d/beautif...      2
# 23  https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 24  https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 25  https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 26  https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 27  https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2
# 28  https://sfbay.craigslist.org/sfc/apa/d/san-fra...      2

# %%
# Export raw data to Excel for webpage
apt_df.to_excel("python/AptDataRaw.xlsx", index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-48-fcf40df34710> in <module>
#       1 # Export raw data to Excel for webpage
# ----> 2 apt_df.to_excel("python/AptDataRaw.xlsx", index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    1764         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    1765                         startcol=startcol, freeze_panes=freeze_panes,
# -> 1766                         engine=engine)
#    1767
#    1768     def to_stata(self, fname, convert_dates=None, write_index=True,
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     652                            freeze_panes=freeze_panes)
#     653         if need_save:
# --> 654             writer.save()
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel.py in save(self)
#    1730         """
#    1731
# -> 1732         return self.book.close()
#    1733
#    1734     def write_cells(self, cells, sheet_name=None, startrow=0, startcol=0,
#
# ~\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     304         if not self.fileclosed:
#     305             self.fileclosed = 1
# --> 306             self._store_workbook()
#     307
#     308     def set_size(self, width, height):
#
# ~\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     653
#     654         xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
# --> 655                             allowZip64=self.allow_zip64)
#     656
#     657         # Add XML sub-files to the Zip file with their Excel filename.
#
# ~\Anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1202             while True:
#    1203                 try:
# -> 1204                     self.fp = io.open(file, filemode)
#    1205                 except OSError:
#    1206                     if filemode in modeDict:
#
# PermissionError: [Errno 13] Permission denied: 'python/AptDataRaw.xlsx'

# %%
# Clean data and remove text from #bedrooms and create new column for sqft 

# Split before and after the dash & remove the 'ft2' text
apt_df['#bedrooms'] = apt_df['#bedrooms'].astype(str)
apt_df['#bedrooms'] = apt_df['#bedrooms'].str.split(',').str[2]
apt_df['#bedrooms'].fillna("", inplace=True)
apt_df['#bedrooms'] = apt_df['#bedrooms'].str.split('ft2') 

###############################################################

# Loop through the new bedroom values and remove remaining text that will prevent converting to int
bedrooms = apt_df['#bedrooms']
rooms = []

for room in bedrooms:
    rooms.append(room[0].strip(','))

apt_df['sqft'] = rooms
apt_df['sqft'] = apt_df['sqft'].str.replace(r"'", '')
apt_df['sqft'] = apt_df['sqft'].astype(str)
apt_df['sqft'] = apt_df['sqft'].str.strip()

##############################################################

# Convert values to int and if NAN make = 0
sqfts = apt_df['sqft']
number = []

for sqft in sqfts:
    number.append(sqft)

newsqft = pd.to_numeric(number, errors='ignore')
apt_df['sqft'] = newsqft
apt_df['sqft'].fillna("0", inplace=True)
apt_df['sqft'] = apt_df['sqft'].astype(int)

##############################################################

# Convert price and # rooms to int in order to graph data
apt_df['$price'] = apt_df['$price'].astype(int)
apt_df['#rooms'] = apt_df['#rooms'].astype(int)


##############################################################

# Clean up the Neighborhood name
apt_df['Hood'] = apt_df['Neighborhood'].str.extract(r"\((.*?)\)", expand=False)
apt_df['Hood'] = apt_df['Hood'].astype(str)
apt_df['Hood'] = apt_df['Hood'].str.strip()

neighborhoods = apt_df["Hood"].unique()
new_hoods = ['North Beach', 'Lower Nob Hill', 'Nob Hill', 'Russian Hill', 'Lower Pac Hts', 'Pac Heights']
my_dict = dict(zip(neighborhoods, new_hoods))

apt_df['Hood'].replace(my_dict, inplace=True)


apt_df
# Out:
#       #bedrooms  $price                     Neighborhood   Post_Time  \
# 0            []    3495                  (lower pac hts)  2019-02-13
# 1    [ '850, ']    2900                  (lower pac hts)  2019-02-13
# 2    [ '675, ']    3300                       (nob hill)  2019-02-13
# 3    [ '675, ']    3100                       (nob hill)  2019-02-13
# 4            []    3300                 (lower nob hill)  2019-02-13
# 5    [ '900, ']     670            (marina / cow hollow)  2019-02-13
# 6   [ '1038, ']    3500                   (russian hill)  2019-02-13
# 7            []    3250                       (nob hill)  2019-02-12
# 8            []    3450   (north beach / telegraph hill)  2019-02-12
# 9            []    3095                 (lower nob hill)  2019-02-12
# 10   [ '850, ']    3100                       (nob hill)  2019-02-12
# 11           []    3095                 (lower nob hill)  2019-02-11
# 12   [ '750, ']    3495                       (nob hill)  2019-02-11
# 13   [ '515, ']    2988                       (nob hill)  2019-02-11
# 14           []    2950                       (nob hill)  2019-02-11
# 15           []    3500   (north beach / telegraph hill)  2019-02-11
# 16           []    3400                       (nob hill)  2019-02-10
# 17           []    3400                       (nob hill)  2019-02-10
# 18           []    3395                 (lower nob hill)  2019-02-10
# 19     [ '1, ']    2000                   (russian hill)  2019-02-10
# 20   [ '850, ']    2950                  (lower pac hts)  2019-02-10
# 21           []    1850                 (lower nob hill)  2019-02-09
# 22           []    3400                  (lower pac hts)  2019-02-09
# 23   [ '900, ']    2999   (north beach / telegraph hill)  2019-02-09
# 24   [ '675, ']    2700                       (nob hill)  2019-02-08
# 25           []    3500                (pacific heights)  2019-02-08
# 26           []    3195                       (nob hill)  2019-02-07
# 27           []    3150                       (nob hill)  2019-02-06
# 28   [ '800, ']    3000                       (nob hill)  2019-02-06
#
#                                            Post_Title  \
# 0             Modern 2BR/1BA in Lower Pacific Heights
# 1   SUTTER ST NR. PRESIDIO 2 BR APT. EXC. DESIRABL...
# 2                           2 Bedrooms flat -  1 Bath
# 3                           2 Bedrooms flat -  1 Bath
# 4   2 BED SUNNY Remodeled; hdwd, quartz, Micro, di...
# 5       Gold Mine Dr 2 Beds 1 Bath 900 sqft For Rent.
# 6              Stunning unit with clean modern design
# 7   2 bedroom with hardwood and large rooms near Polk
# 8   Prime North Beach, Union @ Stockton 2BR/1BA, g...
# 9     Bright and Spacious - Newly renovated 1Br w/Den
# 10  Hyde/Clay Sts 2 bdrm, liv rm, xtra bonus rm, c...
# 11    Bright and Spacious - Newly renovated 1Br w/Den
# 12                        New Two Bedroom in Nob Hill
# 13         2 bedroom ​freshly remodeled. Clay & Mason
# 14  2 Bedroom 1 Bathroom Recently Renovated Apt Av...
# 15         Charming 2/1, HW, laundry, great location!
# 16                     2 BR Available For Rent- $3400
# 17                     2 BR Available For Rent- $3400
# 18  721 Geary #5 - $95 Move-In Special - Available...
# 19               Room for Rent : 2 bedroom/1 bathroom
# 20  SUTTER ST NR. PRESIDIO 2 BR APT. EXC. DESIRABL...
# 21  One room in 2bd 1bath apartment in lower nob hill
# 22              Beautiful Apartment-Lower Pac Heights
# 23  2-3 Bedrooms + Bonus room + Split bathroom for...
# 24                    2 bedroom, 1 bathroom apartment
# 25                           Conveniently Located 2BR
# 26  Beautiful 2 Bedroom 1 Bath with 2 Big Walking ...
# 27    Spacious Floor Plan Loacted in Fun Neighborhood
# 28  Pine/Powell Sts 4 rm, 2 bd, liv rm, wd laminat...
#
#                                                   URL  #rooms  sqft  \
# 0   https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2     0
# 1   https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2   850
# 2   https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2   675
# 3   https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2   675
# 4   https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2     0
# 5   https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2   900
# 6   https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2  1038
# 7   https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2     0
# 8   https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2     0
# 9   https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2     0
# 10  https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2   850
# 11  https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2     0
# 12  https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2   750
# 13  https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2   515
# 14  https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2     0
# 15  https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2     0
# 16  https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2     0
# 17  https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2     0
# 18  https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2     0
# 19  https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2     1
# 20  https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2   850
# 21  https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2     0
# 22  https://sfbay.craigslist.org/sfc/apa/d/beautif...       2     0
# 23  https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2   900
# 24  https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2   675
# 25  https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2     0
# 26  https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2     0
# 27  https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2     0
# 28  https://sfbay.craigslist.org/sfc/apa/d/san-fra...       2   800
#
#                Hood
# 0       North Beach
# 1       North Beach
# 2    Lower Nob Hill
# 3    Lower Nob Hill
# 4          Nob Hill
# 5      Russian Hill
# 6     Lower Pac Hts
# 7    Lower Nob Hill
# 8       Pac Heights
# 9          Nob Hill
# 10   Lower Nob Hill
# 11         Nob Hill
# 12   Lower Nob Hill
# 13   Lower Nob Hill
# 14   Lower Nob Hill
# 15      Pac Heights
# 16   Lower Nob Hill
# 17   Lower Nob Hill
# 18         Nob Hill
# 19    Lower Pac Hts
# 20      North Beach
# 21         Nob Hill
# 22      North Beach
# 23      Pac Heights
# 24   Lower Nob Hill
# 25  pacific heights
# 26   Lower Nob Hill
# 27   Lower Nob Hill
# 28   Lower Nob Hill

# %%
# New DataFrame to build graphs in
apts_data = apt_df[['#rooms', 'sqft', '$price', 'Hood', 'Post_Time', 'Post_Title', 'URL']]

apts_data.dtypes
# Out:
# #rooms         int32
# sqft           int32
# $price         int32
# Hood          object
# Post_Time     object
# Post_Title    object
# URL           object
# dtype: object

# %%
# Export data to Excel for webpage
apts_data.to_excel("python/AptData.xlsx", index=False)

# %% [markdown]
# # <font color=salmon> Send data to SlackBot </font>

# %%
import os
from slackclient import SlackClient
import pprint
from collections import Counter

# %%
slack_data = apts_data.to_dict('records')
str(slack_data)
slack_data
# Out:
# [{'#rooms': 2,
#   'sqft': 0,
#   '$price': 3495,
#   'Hood': 'North Beach',
#   'Post_Time': datetime.date(2019, 2, 13),
#   'Post_Title': 'Modern 2BR/1BA in Lower Pacific Heights',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-modern-2br-1ba-in-lower/6818662471.html'},
#  {'#rooms': 2,
#   'sqft': 850,
#   '$price': 2900,
#   'Hood': 'North Beach',
#   'Post_Time': datetime.date(2019, 2, 13),
#   'Post_Title': 'SUTTER ST NR. PRESIDIO 2 BR APT. EXC. DESIRABLE LOCATIO & GREAT TRANS.',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-sutter-st-nr-presidio-2/6796761973.html'},
#  {'#rooms': 2,
#   'sqft': 675,
#   '$price': 3300,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 13),
#   'Post_Title': '2 Bedrooms flat -  1 Bath',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedrooms-flat-1-bath/6808841627.html'},
#  {'#rooms': 2,
#   'sqft': 675,
#   '$price': 3100,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 13),
#   'Post_Title': '2 Bedrooms flat -  1 Bath',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedrooms-flat-1-bath/6808839802.html'},
#  {'#rooms': 2,
#   'sqft': 0,
#   '$price': 3300,
#   'Hood': 'Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 13),
#   'Post_Title': '2 BED SUNNY Remodeled; hdwd, quartz, Micro, dishwasher; 4 closets;',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bed-sunny-remodeled/6815279146.html'},
#  {'#rooms': 2,
#   'sqft': 900,
#   '$price': 670,
#   'Hood': 'Russian Hill',
#   'Post_Time': datetime.date(2019, 2, 13),
#   'Post_Title': 'Gold Mine Dr 2 Beds 1 Bath 900 sqft For Rent.',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-gold-mine-dr-2-beds-1/6818364855.html'},
#  {'#rooms': 2,
#   'sqft': 1038,
#   '$price': 3500,
#   'Hood': 'Lower Pac Hts',
#   'Post_Time': datetime.date(2019, 2, 13),
#   'Post_Title': 'Stunning unit with clean modern design',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-stunning-unit-with-clean/6818229683.html'},
#  {'#rooms': 2,
#   'sqft': 0,
#   '$price': 3250,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 12),
#   'Post_Title': '2 bedroom with hardwood and large rooms near Polk',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedroom-with-hardwood/6818165978.html'},
#  {'#rooms': 2,
#   'sqft': 0,
#   '$price': 3450,
#   'Hood': 'Pac Heights',
#   'Post_Time': datetime.date(2019, 2, 12),
#   'Post_Title': 'Prime North Beach, Union @ Stockton 2BR/1BA, good size unit for rent..',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-prime-north-beach-union/6813029028.html'},
#  {'#rooms': 2,
#   'sqft': 0,
#   '$price': 3095,
#   'Hood': 'Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 12),
#   'Post_Title': 'Bright and Spacious - Newly renovated 1Br w/Den',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-bright-and-spacious-newly/6816304843.html'},
#  {'#rooms': 2,
#   'sqft': 850,
#   '$price': 3100,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 12),
#   'Post_Title': 'Hyde/Clay Sts 2 bdrm, liv rm, xtra bonus rm, carpet, lar kit, grt loc',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-hyde-clay-sts-2-bdrm-liv/6817385660.html'},
#  {'#rooms': 2,
#   'sqft': 0,
#   '$price': 3095,
#   'Hood': 'Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 11),
#   'Post_Title': 'Bright and Spacious - Newly renovated 1Br w/Den',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-bright-and-spacious-newly/6813415853.html'},
#  {'#rooms': 2,
#   'sqft': 750,
#   '$price': 3495,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 11),
#   'Post_Title': 'New Two Bedroom in Nob Hill',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-new-two-bedroom-in-nob/6814853385.html'},
#  {'#rooms': 2,
#   'sqft': 515,
#   '$price': 2988,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 11),
#   'Post_Title': '2 bedroom \u200bfreshly remodeled. Clay & Mason',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedroom-freshly/6817218156.html'},
#  {'#rooms': 2,
#   'sqft': 0,
#   '$price': 2950,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 11),
#   'Post_Title': '2 Bedroom 1 Bathroom Recently Renovated Apt Available April 1',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedroom-1-bathroom/6817209145.html'},
#  {'#rooms': 2,
#   'sqft': 0,
#   '$price': 3500,
#   'Hood': 'Pac Heights',
#   'Post_Time': datetime.date(2019, 2, 11),
#   'Post_Title': 'Charming 2/1, HW, laundry, great location!',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-charming-2-1-hw-laundry/6814658751.html'},
#  {'#rooms': 2,
#   'sqft': 0,
#   '$price': 3400,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 10),
#   'Post_Title': '2 BR Available For Rent- $3400',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-br-available-for-rent/6816486801.html'},
#  {'#rooms': 2,
#   'sqft': 0,
#   '$price': 3400,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 10),
#   'Post_Title': '2 BR Available For Rent- $3400',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-br-available-for-rent/6816486616.html'},
#  {'#rooms': 2,
#   'sqft': 0,
#   '$price': 3395,
#   'Hood': 'Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 10),
#   'Post_Title': '721 Geary #5 - $95 Move-In Special - Available Now!',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-721-geary-5-95-move-in/6796974937.html'},
#  {'#rooms': 2,
#   'sqft': 1,
#   '$price': 2000,
#   'Hood': 'Lower Pac Hts',
#   'Post_Time': datetime.date(2019, 2, 10),
#   'Post_Title': 'Room for Rent : 2 bedroom/1 bathroom',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-room-for-rent-2-bedroom-1/6816470635.html'},
#  {'#rooms': 2,
#   'sqft': 850,
#   '$price': 2950,
#   'Hood': 'North Beach',
#   'Post_Time': datetime.date(2019, 2, 10),
#   'Post_Title': 'SUTTER ST NR. PRESIDIO 2 BR APT. EXC. DESIRABLE LOCATIO & GREAT TRANS.',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-sutter-st-nr-presidio-2/6806241723.html'},
#  {'#rooms': 2,
#   'sqft': 0,
#   '$price': 1850,
#   'Hood': 'Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 9),
#   'Post_Title': 'One room in 2bd 1bath apartment in lower nob hill',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-one-room-in-2bd-1bath/6815860090.html'},
#  {'#rooms': 2,
#   'sqft': 0,
#   '$price': 3400,
#   'Hood': 'North Beach',
#   'Post_Time': datetime.date(2019, 2, 9),
#   'Post_Title': 'Beautiful Apartment-Lower Pac Heights',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/beautiful-apartment-lower-pac-heights/6815538294.html'},
#  {'#rooms': 2,
#   'sqft': 900,
#   '$price': 2999,
#   'Hood': 'Pac Heights',
#   'Post_Time': datetime.date(2019, 2, 9),
#   'Post_Title': '2-3 Bedrooms + Bonus room + Split bathroom for Rent in North Beach',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-3-bedrooms-bonus-room/6815507957.html'},
#  {'#rooms': 2,
#   'sqft': 675,
#   '$price': 2700,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 8),
#   'Post_Title': '2 bedroom, 1 bathroom apartment',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedroom-1-bathroom/6811835800.html'},
#  {'#rooms': 2,
#   'sqft': 0,
#   '$price': 3500,
#   'Hood': 'pacific heights',
#   'Post_Time': datetime.date(2019, 2, 8),
#   'Post_Title': 'Conveniently Located 2BR',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-conveniently-located-2br/6814406969.html'},
#  {'#rooms': 2,
#   'sqft': 0,
#   '$price': 3195,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 7),
#   'Post_Title': 'Beautiful 2 Bedroom 1 Bath with 2 Big Walking Closets',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-beautiful-2-bedroom-1/6813850217.html'},
#  {'#rooms': 2,
#   'sqft': 0,
#   '$price': 3150,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 6),
#   'Post_Title': 'Spacious Floor Plan Loacted in Fun Neighborhood',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-spacious-floor-plan/6807701982.html'},
#  {'#rooms': 2,
#   'sqft': 800,
#   '$price': 3000,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 6),
#   'Post_Title': 'Pine/Powell Sts 4 rm, 2 bd, liv rm, wd laminate flr, nr fin distric',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-pine-powell-sts-4-rm-2-bd/6813040619.html'}]

# %%
# Convert dictionary data to CSV 
dict_data =(pd.DataFrame.from_dict(data=slack_data, orient='columns').to_csv('python/DictData.csv', header=False))

# %%
# Prints the nicely formatted dictionary
pprint.pprint(slack_data)

# Sets 'pretty_dict_str' to 
pretty_dict_str = pprint.pformat(slack_data)
# Out:
# [{'#rooms': 2,
#   '$price': 3495,
#   'Hood': 'North Beach',
#   'Post_Time': datetime.date(2019, 2, 13),
#   'Post_Title': 'Modern 2BR/1BA in Lower Pacific Heights',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-modern-2br-1ba-in-lower/6818662471.html',
#   'sqft': 0},
#  {'#rooms': 2,
#   '$price': 2900,
#   'Hood': 'North Beach',
#   'Post_Time': datetime.date(2019, 2, 13),
#   'Post_Title': 'SUTTER ST NR. PRESIDIO 2 BR APT. EXC. DESIRABLE LOCATIO & '
#                 'GREAT TRANS.',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-sutter-st-nr-presidio-2/6796761973.html',
#   'sqft': 850},
#  {'#rooms': 2,
#   '$price': 3300,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 13),
#   'Post_Title': '2 Bedrooms flat -  1 Bath',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedrooms-flat-1-bath/6808841627.html',
#   'sqft': 675},
#  {'#rooms': 2,
#   '$price': 3100,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 13),
#   'Post_Title': '2 Bedrooms flat -  1 Bath',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedrooms-flat-1-bath/6808839802.html',
#   'sqft': 675},
#  {'#rooms': 2,
#   '$price': 3300,
#   'Hood': 'Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 13),
#   'Post_Title': '2 BED SUNNY Remodeled; hdwd, quartz, Micro, dishwasher; 4 '
#                 'closets;',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bed-sunny-remodeled/6815279146.html',
#   'sqft': 0},
#  {'#rooms': 2,
#   '$price': 670,
#   'Hood': 'Russian Hill',
#   'Post_Time': datetime.date(2019, 2, 13),
#   'Post_Title': 'Gold Mine Dr 2 Beds 1 Bath 900 sqft For Rent.',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-gold-mine-dr-2-beds-1/6818364855.html',
#   'sqft': 900},
#  {'#rooms': 2,
#   '$price': 3500,
#   'Hood': 'Lower Pac Hts',
#   'Post_Time': datetime.date(2019, 2, 13),
#   'Post_Title': 'Stunning unit with clean modern design',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-stunning-unit-with-clean/6818229683.html',
#   'sqft': 1038},
#  {'#rooms': 2,
#   '$price': 3250,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 12),
#   'Post_Title': '2 bedroom with hardwood and large rooms near Polk',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedroom-with-hardwood/6818165978.html',
#   'sqft': 0},
#  {'#rooms': 2,
#   '$price': 3450,
#   'Hood': 'Pac Heights',
#   'Post_Time': datetime.date(2019, 2, 12),
#   'Post_Title': 'Prime North Beach, Union @ Stockton 2BR/1BA, good size unit '
#                 'for rent..',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-prime-north-beach-union/6813029028.html',
#   'sqft': 0},
#  {'#rooms': 2,
#   '$price': 3095,
#   'Hood': 'Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 12),
#   'Post_Title': 'Bright and Spacious - Newly renovated 1Br w/Den',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-bright-and-spacious-newly/6816304843.html',
#   'sqft': 0},
#  {'#rooms': 2,
#   '$price': 3100,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 12),
#   'Post_Title': 'Hyde/Clay Sts 2 bdrm, liv rm, xtra bonus rm, carpet, lar kit, '
#                 'grt loc',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-hyde-clay-sts-2-bdrm-liv/6817385660.html',
#   'sqft': 850},
#  {'#rooms': 2,
#   '$price': 3095,
#   'Hood': 'Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 11),
#   'Post_Title': 'Bright and Spacious - Newly renovated 1Br w/Den',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-bright-and-spacious-newly/6813415853.html',
#   'sqft': 0},
#  {'#rooms': 2,
#   '$price': 3495,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 11),
#   'Post_Title': 'New Two Bedroom in Nob Hill',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-new-two-bedroom-in-nob/6814853385.html',
#   'sqft': 750},
#  {'#rooms': 2,
#   '$price': 2988,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 11),
#   'Post_Title': '2 bedroom \u200bfreshly remodeled. Clay & Mason',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedroom-freshly/6817218156.html',
#   'sqft': 515},
#  {'#rooms': 2,
#   '$price': 2950,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 11),
#   'Post_Title': '2 Bedroom 1 Bathroom Recently Renovated Apt Available April 1',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedroom-1-bathroom/6817209145.html',
#   'sqft': 0},
#  {'#rooms': 2,
#   '$price': 3500,
#   'Hood': 'Pac Heights',
#   'Post_Time': datetime.date(2019, 2, 11),
#   'Post_Title': 'Charming 2/1, HW, laundry, great location!',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-charming-2-1-hw-laundry/6814658751.html',
#   'sqft': 0},
#  {'#rooms': 2,
#   '$price': 3400,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 10),
#   'Post_Title': '2 BR Available For Rent- $3400',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-br-available-for-rent/6816486801.html',
#   'sqft': 0},
#  {'#rooms': 2,
#   '$price': 3400,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 10),
#   'Post_Title': '2 BR Available For Rent- $3400',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-br-available-for-rent/6816486616.html',
#   'sqft': 0},
#  {'#rooms': 2,
#   '$price': 3395,
#   'Hood': 'Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 10),
#   'Post_Title': '721 Geary #5 - $95 Move-In Special - Available Now!',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-721-geary-5-95-move-in/6796974937.html',
#   'sqft': 0},
#  {'#rooms': 2,
#   '$price': 2000,
#   'Hood': 'Lower Pac Hts',
#   'Post_Time': datetime.date(2019, 2, 10),
#   'Post_Title': 'Room for Rent : 2 bedroom/1 bathroom',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-room-for-rent-2-bedroom-1/6816470635.html',
#   'sqft': 1},
#  {'#rooms': 2,
#   '$price': 2950,
#   'Hood': 'North Beach',
#   'Post_Time': datetime.date(2019, 2, 10),
#   'Post_Title': 'SUTTER ST NR. PRESIDIO 2 BR APT. EXC. DESIRABLE LOCATIO & '
#                 'GREAT TRANS.',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-sutter-st-nr-presidio-2/6806241723.html',
#   'sqft': 850},
#  {'#rooms': 2,
#   '$price': 1850,
#   'Hood': 'Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 9),
#   'Post_Title': 'One room in 2bd 1bath apartment in lower nob hill',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-one-room-in-2bd-1bath/6815860090.html',
#   'sqft': 0},
#  {'#rooms': 2,
#   '$price': 3400,
#   'Hood': 'North Beach',
#   'Post_Time': datetime.date(2019, 2, 9),
#   'Post_Title': 'Beautiful Apartment-Lower Pac Heights',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/beautiful-apartment-lower-pac-heights/6815538294.html',
#   'sqft': 0},
#  {'#rooms': 2,
#   '$price': 2999,
#   'Hood': 'Pac Heights',
#   'Post_Time': datetime.date(2019, 2, 9),
#   'Post_Title': '2-3 Bedrooms + Bonus room + Split bathroom for Rent in North '
#                 'Beach',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-3-bedrooms-bonus-room/6815507957.html',
#   'sqft': 900},
#  {'#rooms': 2,
#   '$price': 2700,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 8),
#   'Post_Title': '2 bedroom, 1 bathroom apartment',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedroom-1-bathroom/6811835800.html',
#   'sqft': 675},
#  {'#rooms': 2,
#   '$price': 3500,
#   'Hood': 'pacific heights',
#   'Post_Time': datetime.date(2019, 2, 8),
#   'Post_Title': 'Conveniently Located 2BR',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-conveniently-located-2br/6814406969.html',
#   'sqft': 0},
#  {'#rooms': 2,
#   '$price': 3195,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 7),
#   'Post_Title': 'Beautiful 2 Bedroom 1 Bath with 2 Big Walking Closets',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-beautiful-2-bedroom-1/6813850217.html',
#   'sqft': 0},
#  {'#rooms': 2,
#   '$price': 3150,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 6),
#   'Post_Title': 'Spacious Floor Plan Loacted in Fun Neighborhood',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-spacious-floor-plan/6807701982.html',
#   'sqft': 0},
#  {'#rooms': 2,
#   '$price': 3000,
#   'Hood': 'Lower Nob Hill',
#   'Post_Time': datetime.date(2019, 2, 6),
#   'Post_Title': 'Pine/Powell Sts 4 rm, 2 bd, liv rm, wd laminate flr, nr fin '
#                 'distric',
#   'URL': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-pine-powell-sts-4-rm-2-bd/6813040619.html',
#   'sqft': 800}]

# %%
SLACK_TOKEN = "xoxp-550950830294-549370340868-549375843396-20ae645601759850f57d332b847344d4"
SLACK_CHANNEL = "#housing"

sc = SlackClient(SLACK_TOKEN)

sc.api_call(
    "chat.postMessage", channel=SLACK_CHANNEL, text=pretty_dict_str,
    username='pybot', icon_emoji=':robot_face:'
)
# Out:
# {'ok': True,
#  'channel': 'CG4PC5PQQ',
#  'ts': '1550063933.000200',
#  'message': {'type': 'message',
#   'subtype': 'bot_message',
#   'text': "  'URL': '<https://sfbay.craigslist.org/sfc/apa/d/san-francisco-sutter-st-nr-presidio-2/6806241723.html>',\n  'sqft': 850},\n {'#rooms': 2,\n  '$price': 1850,\n  'Hood': 'Nob Hill',\n  'Post_Time': datetime.date(2019, 2, 9),\n  'Post_Title': 'One room in 2bd 1bath apartment in lower nob hill',\n  'URL': '<https://sfbay.craigslist.org/sfc/apa/d/san-francisco-one-room-in-2bd-1bath/6815860090.html>',\n  'sqft': 0},\n {'#rooms': 2,\n  '$price': 3400,\n  'Hood': 'Lower Pac Hts',\n  'Post_Time': datetime.date(2019, 2, 9),\n  'Post_Title': 'Beautiful Apartment-Lower Pac Heights',\n  'URL': '<https://sfbay.craigslist.org/sfc/apa/d/beautiful-apartment-lower-pac-heights/6815538294.html>',\n  'sqft': 0},\n {'#rooms': 2,\n  '$price': 2999,\n  'Hood': 'Lower Nob Hill',\n  'Post_Time': datetime.date(2019, 2, 9),\n  'Post_Title': '2-3 Bedrooms + Bonus room + Split bathroom for Rent in North '\n                'Beach',\n  'URL': '<https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-3-bedrooms-bonus-room/6815507957.html>',\n  'sqft': 900},\n {'#rooms': 2,\n  '$price': 3300,\n  'Hood': 'Nob Hill',\n  'Post_Time': datetime.date(2019, 2, 9),\n  'Post_Title': '2 BED SUNNY Remodeled; hdwd, quartz, Micro, dishwasher; 4 '\n                'closets;',\n  'URL': '<https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bed-sunny-remodeled/6815279146.html>',\n  'sqft': 0},\n {'#rooms': 2,\n  '$price': 2700,\n  'Hood': 'North Beach',\n  'Post_Time': datetime.date(2019, 2, 8),\n  'Post_Title': '2 bedroom, 1 bathroom apartment',\n  'URL': '<https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedroom-1-bathroom/6811835800.html>',\n  'sqft': 675},\n {'#rooms': 2,\n  '$price': 2900,\n  'Hood': 'Lower Pac Hts',\n  'Post_Time': datetime.date(2019, 2, 8),\n  'Post_Title': 'SUTTER ST NR. PRESIDIO 2 BR APT. EXC. DESIRABLE LOCATIO &amp; '\n                'GREAT TRANS.',\n  'URL': '<https://sfbay.craigslist.org/sfc/apa/d/san-francisco-sutter-st-nr-presidio-2/6796761973.html>',\n  'sqft': 850},\n {'#rooms': 2,\n  '$price': 3500,\n  'Hood': 'Pac Heights',\n  'Post_Time': datetime.date(2019, 2, 8),\n  'Post_Title': 'Conveniently Located 2BR',\n  'URL': '<https://sfbay.craigslist.org/sfc/apa/d/san-francisco-conveniently-located-2br/6814406969.html>',\n  'sqft': 0},\n {'#rooms': 2,\n  '$price': 3100,\n  'Hood': 'North Beach',\n  'Post_Time': datetime.date(2019, 2, 7),\n  'Post_Title': '2 Bedrooms flat -  1 Bath',\n  'URL': '<https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedrooms-flat-1-bath/6808839802.html>',\n  'sqft': 675},\n {'#rooms': 2,\n  '$price': 3300,\n  'Hood': 'North Beach',\n  'Post_Time': datetime.date(2019, 2, 7),\n  'Post_Title': '2 Bedrooms flat -  1 Bath',\n  'URL': '<https://sfbay.craigslist.org/sfc/apa/d/san-francisco-2-bedrooms-flat-1-bath/6808841627.html>',\n  'sqft': 675},\n {'#rooms': 2,\n  '$price': 3195,\n  'Hood': 'North Beach',\n  'Post_Time': datetime.date(2019, 2, 7),\n  'Post_Title': 'Beautiful 2 Bedroom 1 Bath with 2 Big Walking Closets',\n  'URL': '<https://sfbay.craigslist.org/sfc/apa/d/san-francisco-beautiful-2-bedroom-1/6813850217.html>',\n  'sqft': 0},\n {'#rooms': 2,\n  '$price': 3150,\n  'Hood': 'North Beach',\n  'Post_Time': datetime.date(2019, 2, 6),\n  'Post_Title': 'Spacious Floor Plan Loacted in Fun Neighborhood',\n  'URL': '<https://sfbay.craigslist.org/sfc/apa/d/san-francisco-spacious-floor-plan/6807701982.html>',\n  'sqft': 0},\n {'#rooms': 2,\n  '$price': 3000,\n  'Hood': 'North Beach',\n  'Post_Time': datetime.date(2019, 2, 6),\n  'Post_Title': 'Pine/Powell Sts 4 rm, 2 bd, liv rm, wd laminate flr, nr fin '\n                'distric',\n  'URL': '<https://sfbay.craigslist.org/sfc/apa/d/san-francisco-pine-powell-sts-4-rm-2-bd/6813040619.html>',\n  'sqft': 800}]",
#   'ts': '1550063933.000200',
#   'username': 'pybot',
#   'icons': {'emoji': ':robot_face:',
#    'image_64': 'https://a.slack-edge.com/37d58/img/emoji_2017_12_06/apple/1f916.png'},
#   'bot_id': 'BG5MRDPC5'},
#  'headers': {'Content-Type': 'application/json; charset=utf-8',
#   'Content-Length': '1127',
#   'Connection': 'keep-alive',
#   'Date': 'Wed, 13 Feb 2019 13:18:53 GMT',
#   'Server': 'Apache',
#   'Expires': 'Mon, 26 Jul 1997 05:00:00 GMT',
#   'X-Content-Type-Options': 'nosniff',
#   'Pragma': 'no-cache',
#   'Vary': 'Accept-Encoding',
#   'X-Accepted-OAuth-Scopes': 'chat:write:bot,post',
#   'X-OAuth-Scopes': 'identify,read,post,client,apps,admin',
#   'Cache-Control': 'private, no-cache, no-store, must-revalidate',
#   'X-XSS-Protection': '0',
#   'X-Slack-Req-Id': '2049f28a-e44e-4559-b6d2-7926dead8bf2',
#   'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload',
#   'Referrer-Policy': 'no-referrer',
#   'Content-Encoding': 'gzip',
#   'Access-Control-Allow-Origin': '*',
#   'X-Via': 'haproxy-www-bmnj',
#   'X-Cache': 'Miss from cloudfront',
#   'Via': '1.1 f90455bc1ae6b17d472e4be0fa0d191e.cloudfront.net (CloudFront)',
#   'X-Amz-Cf-Id': 'XnqHrZVOAuqFdLv-16Ie23KLDBAkvNoJimIlqXghGYQta--_dUtYIA=='}}

# %% [markdown]
# ## <font color=salmon> Build visualizations for analysis </font>

# %%
import matplotlib.pylab as pylab
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
apts_data.describe()
# Out:
#        #rooms         sqft       $price
# count    29.0    29.000000    29.000000
# mean      2.0   326.862069  3038.862069
# std       0.0   405.375463   604.518623
# min       2.0     0.000000   670.000000
# 25%       2.0     0.000000  2988.000000
# 50%       2.0     0.000000  3150.000000
# 75%       2.0   750.000000  3400.000000
# max       2.0  1038.000000  3500.000000

# %% [markdown]
# ### <font color=darksalmon> Word Cloud Visualizations </font>

# %%
hoods = apts_data['Hood']
hoods.sort_values()
# Out:
# 14     Lower Nob Hill
# 26     Lower Nob Hill
# 24     Lower Nob Hill
# 17     Lower Nob Hill
# 16     Lower Nob Hill
# 27     Lower Nob Hill
# 13     Lower Nob Hill
# 12     Lower Nob Hill
# 10     Lower Nob Hill
# 28     Lower Nob Hill
# 7      Lower Nob Hill
# 2      Lower Nob Hill
# 3      Lower Nob Hill
# 19      Lower Pac Hts
# 6       Lower Pac Hts
# 11           Nob Hill
# 4            Nob Hill
# 18           Nob Hill
# 9            Nob Hill
# 21           Nob Hill
# 1         North Beach
# 22        North Beach
# 0         North Beach
# 20        North Beach
# 23        Pac Heights
# 15        Pac Heights
# 8         Pac Heights
# 5        Russian Hill
# 25    pacific heights
# Name: Hood, dtype: object

# %%
word_could_dict = Counter(hoods)
wordcloud = WordCloud(background_color='white', mode = "RGB", width = 2000, height=1000).generate_from_frequencies(word_could_dict)

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
word_could_dict = Counter(hoods)
wordcloud = WordCloud().generate_from_frequencies(word_could_dict)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
wordcloud.to_file('Word_Cloud.png')

# %% [markdown]
# ### <font color=darksalmon> Bar Graph Visualizations </font>

# %%
apts_data.sort_values('sqft',ascending=False)
# Out:
#     #rooms  sqft  $price             Hood   Post_Time  \
# 6        2  1038    3500    Lower Pac Hts  2019-02-13
# 23       2   900    2999      Pac Heights  2019-02-09
# 5        2   900     670     Russian Hill  2019-02-13
# 20       2   850    2950      North Beach  2019-02-10
# 1        2   850    2900      North Beach  2019-02-13
# 10       2   850    3100   Lower Nob Hill  2019-02-12
# 28       2   800    3000   Lower Nob Hill  2019-02-06
# 12       2   750    3495   Lower Nob Hill  2019-02-11
# 3        2   675    3100   Lower Nob Hill  2019-02-13
# 2        2   675    3300   Lower Nob Hill  2019-02-13
# 24       2   675    2700   Lower Nob Hill  2019-02-08
# 13       2   515    2988   Lower Nob Hill  2019-02-11
# 19       2     1    2000    Lower Pac Hts  2019-02-10
# 26       2     0    3195   Lower Nob Hill  2019-02-07
# 25       2     0    3500  pacific heights  2019-02-08
# 27       2     0    3150   Lower Nob Hill  2019-02-06
# 22       2     0    3400      North Beach  2019-02-09
# 21       2     0    1850         Nob Hill  2019-02-09
# 0        2     0    3495      North Beach  2019-02-13
# 18       2     0    3395         Nob Hill  2019-02-10
# 17       2     0    3400   Lower Nob Hill  2019-02-10
# 16       2     0    3400   Lower Nob Hill  2019-02-10
# 15       2     0    3500      Pac Heights  2019-02-11
# 11       2     0    3095         Nob Hill  2019-02-11
# 9        2     0    3095         Nob Hill  2019-02-12
# 8        2     0    3450      Pac Heights  2019-02-12
# 7        2     0    3250   Lower Nob Hill  2019-02-12
# 4        2     0    3300         Nob Hill  2019-02-13
# 14       2     0    2950   Lower Nob Hill  2019-02-11
#
#                                            Post_Title  \
# 6              Stunning unit with clean modern design
# 23  2-3 Bedrooms + Bonus room + Split bathroom for...
# 5       Gold Mine Dr 2 Beds 1 Bath 900 sqft For Rent.
# 20  SUTTER ST NR. PRESIDIO 2 BR APT. EXC. DESIRABL...
# 1   SUTTER ST NR. PRESIDIO 2 BR APT. EXC. DESIRABL...
# 10  Hyde/Clay Sts 2 bdrm, liv rm, xtra bonus rm, c...
# 28  Pine/Powell Sts 4 rm, 2 bd, liv rm, wd laminat...
# 12                        New Two Bedroom in Nob Hill
# 3                           2 Bedrooms flat -  1 Bath
# 2                           2 Bedrooms flat -  1 Bath
# 24                    2 bedroom, 1 bathroom apartment
# 13         2 bedroom ​freshly remodeled. Clay & Mason
# 19               Room for Rent : 2 bedroom/1 bathroom
# 26  Beautiful 2 Bedroom 1 Bath with 2 Big Walking ...
# 25                           Conveniently Located 2BR
# 27    Spacious Floor Plan Loacted in Fun Neighborhood
# 22              Beautiful Apartment-Lower Pac Heights
# 21  One room in 2bd 1bath apartment in lower nob hill
# 0             Modern 2BR/1BA in Lower Pacific Heights
# 18  721 Geary #5 - $95 Move-In Special - Available...
# 17                     2 BR Available For Rent- $3400
# 16                     2 BR Available For Rent- $3400
# 15         Charming 2/1, HW, laundry, great location!
# 11    Bright and Spacious - Newly renovated 1Br w/Den
# 9     Bright and Spacious - Newly renovated 1Br w/Den
# 8   Prime North Beach, Union @ Stockton 2BR/1BA, g...
# 7   2 bedroom with hardwood and large rooms near Polk
# 4   2 BED SUNNY Remodeled; hdwd, quartz, Micro, di...
# 14  2 Bedroom 1 Bathroom Recently Renovated Apt Av...
#
#                                                   URL
# 6   https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 23  https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 5   https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 20  https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 1   https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 10  https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 28  https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 12  https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 3   https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 2   https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 24  https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 13  https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 19  https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 26  https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 25  https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 27  https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 22  https://sfbay.craigslist.org/sfc/apa/d/beautif...
# 21  https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 0   https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 18  https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 17  https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 16  https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 15  https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 11  https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 9   https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 8   https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 7   https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 4   https://sfbay.craigslist.org/sfc/apa/d/san-fra...
# 14  https://sfbay.craigslist.org/sfc/apa/d/san-fra...

# %%
counts = apts_data.Hood.value_counts()
loc_gt2 = counts[counts > 2]

popular_locations = apts_data[apts_data.Hood.isin(loc_gt2.keys())]

plt.figure(figsize=(10,5))
sns.violinplot(x="Hood", y="$price", data=popular_locations, scale="width", inner="stick")
plt.show();

# %%
counts = apts_data.Hood.value_counts()
loc_gt2 = counts[counts > 2]

popular_locations = apts_data[apts_data.Hood.isin(loc_gt2.keys())]

plt.figure(figsize=(10,5))
sns.violinplot(x="Hood", y="$price", data=popular_locations, scale="count")
plt.show();

# %%
sizing = apts_data.loc[apts_data.sqft >= 100.0, :]

sizing.plot.bar('Hood', 'sqft', figsize=(9,9))
plt.ylabel("Sqft Size")
plt.xlabel("Neighborhood")
plt.show();
